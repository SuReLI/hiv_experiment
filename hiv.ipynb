# %% [markdown]
# https://pubmed.ncbi.nlm.nih.gov/20369969/
# Adams BM, Banks HT, Kwon HD, Tran HT. Dynamic multidrug therapies for hiv: optimal and sti control approaches. Math Biosci Eng. 2004 Sep;1(2):223-41. doi: 10.3934/mbe.2004.1.223. PMID: 20369969.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from hiv_patient import HIVPatient

# %% [markdown]
# # simulate unhealthy patient

# %%
patient = HIVPatient(clipping=False,logscale=False)

# %%
s = patient.reset()
dur = 400
nb_steps = int(dur//1e-3)
print(nb_steps)
states = [s]
for i in range(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
npst = np.array(states)
axs[0,0].plot(npst[:,0])
axs[0,0].set_title("T1")
axs[0,1].plot(npst[:,1])
axs[0,1].set_title("T1*")
axs[0,2].plot(npst[:,2])
axs[0,2].set_title("T2")
axs[1,0].plot(npst[:,3])
axs[1,0].set_title("T2*")
axs[1,1].plot(npst[:,4])
axs[1,1].set_title("V")
axs[1,2].plot(npst[:,5])
axs[1,2].set_title("E")

# %%
states[-1]

# %%
print(np.max(npst, axis=0)-np.min(npst, axis=0))

# %% [markdown]
# Ok, so the "infected, unhealthy" state is stable.

# %% [markdown]
# # simulate uninfected patient

# %%
s = patient.reset(mode="uninfected")
dur = 100
nb_steps = int(dur//1e-3)
print(nb_steps)
states = [s]
for i in range(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
npst = np.array(states)
axs[0,0].plot(npst[:,0])
axs[0,0].set_title("T1")
axs[0,1].plot(npst[:,1])
axs[0,1].set_title("T1*")
axs[0,2].plot(npst[:,2])
axs[0,2].set_title("T2")
axs[1,0].plot(npst[:,3])
axs[1,0].set_title("T2*")
axs[1,1].plot(npst[:,4])
axs[1,1].set_title("V")
axs[1,2].plot(npst[:,5])
axs[1,2].set_title("E")

# %%
states[-1]

# %%
print(np.max(npst, axis=0)-np.min(npst, axis=0))

# %% [markdown]
# The "uninfected" state is stable.

# %% [markdown]
# # simulate early infection

# %% [markdown]
# Initialization according to (Adams, 2004) : uninfected + small infection.
#
# The state converges to the "infected, unhealthy" state.

# %%
s = patient.reset(mode="uninfected")
s[1] = 1e-4
s[3] = 1e-4
s[4] = 1
dur = 400
nb_steps = int(dur//1e-3)
print(nb_steps)
states = [s]
for i in range(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
npst = np.array(states)
axs[0,0].plot(npst[:,0])
axs[0,0].set_title("T1")
axs[0,1].plot(npst[:,1])
axs[0,1].set_title("T1*")
axs[0,2].plot(npst[:,2])
axs[0,2].set_title("T2")
axs[1,0].plot(npst[:,3])
axs[1,0].set_title("T2*")
axs[1,1].plot(npst[:,4])
axs[1,1].set_title("V")
axs[1,2].plot(npst[:,5])
axs[1,2].set_title("E")

# %%
states[-1]

# %%
print(np.max(npst, axis=0)-np.min(npst, axis=0))

# %%
np.set_printoptions(precision=3)
np.set_printoptions(suppress=True)
print(np.max(npst, axis=0))
print(np.min(npst, axis=0))

# %% [markdown]
# # simulate infected healthy patient

# %%
s = patient.reset(mode="healthy")
dur = 800
nb_steps = int(dur//1e-3)
print(nb_steps)
states = [s]
for i in range(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
npst = np.array(states)
axs[0,0].plot(npst[:,0])
axs[0,0].set_title("T1")
axs[0,1].plot(npst[:,1])
axs[0,1].set_title("T1*")
axs[0,2].plot(npst[:,2])
axs[0,2].set_title("T2")
axs[1,0].plot(npst[:,3])
axs[1,0].set_title("T2*")
axs[1,1].plot(npst[:,4])
axs[1,1].set_title("V")
axs[1,2].plot(npst[:,5])
axs[1,2].set_title("E")

# %%
states[-1]

# %%
print(np.max(npst, axis=0)-np.min(npst, axis=0))

# %% [markdown]
# The "infected, healthy" state is stable.
#
# Remark : some amplitude on the oscilations of the concentrations of immune effectors.

# %%
np.set_printoptions(precision=3)
np.set_printoptions(suppress=True)
print(np.max(npst, axis=0))
print(np.min(npst, axis=0))

# %% [markdown]
# # simulate infected healthy patient with 25% immunity failure

# %%
s = patient.reset(mode="healthy")
s[5] *= .75
dur = 400
nb_steps = int(dur//1e-3)
print(nb_steps)
states = [s]
for i in range(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
npst = np.array(states)
axs[0,0].plot(npst[:,0])
axs[0,0].set_title("T1")
axs[0,1].plot(npst[:,1])
axs[0,1].set_title("T1*")
axs[0,2].plot(npst[:,2])
axs[0,2].set_title("T2")
axs[1,0].plot(npst[:,3])
axs[1,0].set_title("T2*")
axs[1,1].plot(npst[:,4])
axs[1,1].set_title("V")
axs[1,2].plot(npst[:,5])
axs[1,2].set_title("E")

# %%
states[-1]

# %%
print(np.max(npst, axis=0)-np.min(npst, axis=0))

# %%
np.set_printoptions(precision=3)
np.set_printoptions(suppress=True)
print(np.max(npst, axis=0))
print(np.min(npst, axis=0))

# %% [markdown]
# # State bounds

# %%
from tqdm import trange

patient = HIVPatient(clipping=False,logscale=False)
trajs = []
trajs_title = []
dur = 800
nb_steps = int(dur//1e-3)
# uninfected
s = patient.reset(mode="uninfected")
states = [s]
for i in trange(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)
trajs.append(states)
trajs_title.append("uninfected")

# early infection
s = patient.reset(mode="uninfected")
s[1] = 1e-4
s[3] = 1e-4
s[4] = 1
states = [s]
for i in trange(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)
trajs.append(states)
trajs_title.append("early infection")

# infected healthy
s = patient.reset(mode="healthy")
states = [s]
for i in trange(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)
trajs.append(states)
trajs_title.append("healthy")

# infected healthy with 25% immunity failure
s = patient.reset(mode="healthy")
s[5] *= .75
states = [s]
for i in trange(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)
trajs.append(states)
trajs_title.append("25% immunity fail")
# Out:
# 100%|██████████| 799999/799999 [00:08<00:00, 90368.37it/s]
# 100%|██████████| 799999/799999 [00:08<00:00, 89569.23it/s]
# 100%|██████████| 799999/799999 [00:08<00:00, 89991.62it/s]
# 100%|██████████| 799999/799999 [00:08<00:00, 90993.11it/s]

# %%
nptrajs = np.array(trajs)
print(nptrajs.shape)
# Out:
# (4, 800000, 6)

# %%
print(nptrajs[:,0,:])
print(np.log10(nptrajs[:,0,:]))
# Out:
# [[1.00000e+06 0.00000e+00 3.19800e+03 0.00000e+00 0.00000e+00 1.00000e+01]
#  [1.00000e+06 1.00000e-04 3.19800e+03 1.00000e-04 1.00000e+00 1.00000e+01]
#  [9.67839e+05 7.60000e+01 6.21000e+02 6.00000e+00 4.15000e+02 3.53108e+05]
#  [9.67839e+05 7.60000e+01 6.21000e+02 6.00000e+00 4.15000e+02 2.64831e+05]]
# [[ 6.                -inf  3.50487846        -inf        -inf  1.        ]
#  [ 6.         -4.          3.50487846 -4.          0.          1.        ]
#  [ 5.98580312  1.88081359  2.7930916   0.77815125  2.6180481   5.54790756]
#  [ 5.98580312  1.88081359  2.7930916   0.77815125  2.6180481   5.42296882]]
# /home/emmanuel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log10

# %%
print(np.min(nptrajs, axis=(0,1)))
print(np.max(nptrajs, axis=(0,1)))
# Out:
# [1.42264770e+04 0.00000000e+00 1.17283636e-01 0.00000000e+00
#  0.00000000e+00 1.00000000e+01]
# [1.00000000e+06 5.12971065e+05 3.19800000e+03 2.16706191e+03
#  2.72664124e+06 3.53170605e+05]

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
var_names = ["T1", "T1*", "T2", "T2*", "V", "E"]

for var_idx, ax in enumerate(fig.axes):
    for traj_idx in range(nptrajs.shape[0]):
        ax.plot(nptrajs[traj_idx,:,var_idx], label=trajs_title[traj_idx])
    ax.set_title(var_names[var_idx])
    ax.legend()
# Out:
# /home/emmanuel/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
bounds = np.zeros((2,6))
bounds[1,0] = 1e6
bounds[1,1] = 5e4
bounds[1,2] = 3200
bounds[1,3] = 80
bounds[1,4] = 2.5e5
bounds[1,5] = 353200

nptrajs_clipped = nptrajs.copy()

for i in range(nptrajs_clipped.shape[2]):
    np.clip(nptrajs_clipped[:,:,i], bounds[0,i], bounds[1,i], out=nptrajs_clipped[:,:,i]);

print(np.min(nptrajs_clipped, axis=(0,1)))
print(np.max(nptrajs_clipped, axis=(0,1)))
# Out:
# [1.42264770e+04 0.00000000e+00 1.17283636e-01 0.00000000e+00
#  0.00000000e+00 1.00000000e+01]
# [1.00000000e+06 5.00000000e+04 3.19800000e+03 8.00000000e+01
#  2.50000000e+05 3.53170605e+05]

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
var_names = ["T1", "T1*", "T2", "T2*", "V", "E"]

for var_index, ax in enumerate(fig.axes):
    for traj in range(nptrajs.shape[0]):
        ax.plot(nptrajs_clipped[traj,:,var_index], label=trajs_title[traj])
    ax.set_title(var_names[var_index])
    ax.legend()
# Out:
# /home/emmanuel/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
var_names = ["T1", "T1*", "T2", "T2*", "V", "E"]

for var_index, ax in enumerate(fig.axes):
    for traj in range(nptrajs.shape[0]):
        ax.plot(np.log10(nptrajs_clipped[traj,:,var_index]), label=trajs_title[traj])
    ax.set_title(var_names[var_index])
    ax.legend()
# Out:
# /home/emmanuel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log10
#
# /home/emmanuel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log10
#
# /home/emmanuel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in log10
#
# /home/emmanuel/anaconda3/lib/python3.7/site-packages/IPython/core/pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Test step() function

# %%
s = patient.reset(mode="healthy")
s[5] *= .75
patient.E *= .75
print(patient.E)
dur = 80 # 400/5
nb_steps = int(dur//1e-3)
states = [s]
for i in range(dur):
    s, r, d, _ = patient.step(0)
    states.append(s)

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
npst = np.array(states)
axs[0,0].plot(npst[:,0])
axs[0,0].set_title("T1")
axs[0,1].plot(npst[:,1])
axs[0,1].set_title("T1*")
axs[0,2].plot(npst[:,2])
axs[0,2].set_title("T2")
axs[1,0].plot(npst[:,3])
axs[1,0].set_title("T2*")
axs[1,1].plot(npst[:,4])
axs[1,1].set_title("V")
axs[1,2].plot(npst[:,5])
axs[1,2].set_title("E")
