# %% [markdown]
# https://pubmed.ncbi.nlm.nih.gov/20369969/
# Adams BM, Banks HT, Kwon HD, Tran HT. Dynamic multidrug therapies for hiv: optimal and sti control approaches. Math Biosci Eng. 2004 Sep;1(2):223-41. doi: 10.3934/mbe.2004.1.223. PMID: 20369969.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from hiv_patient import HIVPatient

# %% [markdown]
# # simulate unhealthy patient

# %%
patient = HIVPatient(clipping=False,logscale=False)

# %%
s = patient.reset()
dur = 400
nb_steps = int(dur//1e-3)
print(nb_steps)
states = [s]
for i in range(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)
# Out:
# 399999

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
npst = np.array(states)
axs[0,0].plot(npst[:,0])
axs[0,0].set_title("T1")
axs[0,1].plot(npst[:,1])
axs[0,1].set_title("T1*")
axs[0,2].plot(npst[:,2])
axs[0,2].set_title("T2")
axs[1,0].plot(npst[:,3])
axs[1,0].set_title("T2*")
axs[1,1].plot(npst[:,4])
axs[1,1].set_title("V")
axs[1,2].plot(npst[:,5])
axs[1,2].set_title("E")
# Out:
# Text(0.5, 1.0, 'E')

# %%
states[-1]
# Out:
# array([1.63572752e+05, 1.19449431e+04, 4.99542354e+00, 4.55990142e+01,
#        6.39185958e+04, 2.35439779e+01])

# %%
print(np.max(npst, axis=0)-np.min(npst, axis=0))
# Out:
# [2.08064713 0.56658123 0.00473999 0.40115465 4.02607717 0.45602213]

# %% [markdown]
# Ok, so the "infected, unhealthy" state is stable.

# %% [markdown]
# # simulate uninfected patient

# %%
s = patient.reset(mode="uninfected")
dur = 100
nb_steps = int(dur//1e-3)
print(nb_steps)
states = [s]
for i in range(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)
# Out:
# 99999

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
npst = np.array(states)
axs[0,0].plot(npst[:,0])
axs[0,0].set_title("T1")
axs[0,1].plot(npst[:,1])
axs[0,1].set_title("T1*")
axs[0,2].plot(npst[:,2])
axs[0,2].set_title("T2")
axs[1,0].plot(npst[:,3])
axs[1,0].set_title("T2*")
axs[1,1].plot(npst[:,4])
axs[1,1].set_title("V")
axs[1,2].plot(npst[:,5])
axs[1,2].set_title("E")
# Out:
# Text(0.5, 1.0, 'E')

# %%
states[-1]
# Out:
# array([1.000e+06, 0.000e+00, 3.198e+03, 0.000e+00, 0.000e+00, 1.000e+01])

# %%
print(np.max(npst, axis=0)-np.min(npst, axis=0))
# Out:
# [0. 0. 0. 0. 0. 0.]

# %% [markdown]
# The "uninfected" state is stable.

# %% [markdown]
# # simulate early infection

# %% [markdown]
# Initialization according to (Adams, 2004) : uninfected + small infection.
#
# The state converges to the "infected, unhealthy" state.

# %%
s = patient.reset(mode="uninfected")
s[1] = 1e-4
s[3] = 1e-4
s[4] = 1
dur = 400
nb_steps = int(dur//1e-3)
print(nb_steps)
states = [s]
for i in range(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)
# Out:
# 399999

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
npst = np.array(states)
axs[0,0].plot(npst[:,0])
axs[0,0].set_title("T1")
axs[0,1].plot(npst[:,1])
axs[0,1].set_title("T1*")
axs[0,2].plot(npst[:,2])
axs[0,2].set_title("T2")
axs[1,0].plot(npst[:,3])
axs[1,0].set_title("T2*")
axs[1,1].plot(npst[:,4])
axs[1,1].set_title("V")
axs[1,2].plot(npst[:,5])
axs[1,2].set_title("E")
# Out:
# Text(0.5, 1.0, 'E')

# %%
states[-1]
# Out:
# array([1.63571830e+05, 1.19452126e+04, 4.99530694e+00, 4.55989980e+01,
#        6.39200539e+04, 2.35439684e+01])

# %%
print(np.max(npst, axis=0)-np.min(npst, axis=0))
# Out:
# [9.85773523e+05 5.12971065e+05 3.19788272e+03 2.16706181e+03
#  2.72664085e+06 3.80826835e+01]

# %%
np.set_printoptions(precision=3)
np.set_printoptions(suppress=True)
print(np.max(npst, axis=0))
print(np.min(npst, axis=0))
# Out:
# [1000000.     512971.065    3198.       2167.062 2726641.237      48.083]
# [14226.477     0.        0.117     0.        0.391    10.   ]

# %% [markdown]
# # simulate infected healthy patient

# %%
s = patient.reset(mode="healthy")
dur = 800
nb_steps = int(dur//1e-3)
print(nb_steps)
states = [s]
for i in range(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)
# Out:
# 799999

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
npst = np.array(states)
axs[0,0].plot(npst[:,0])
axs[0,0].set_title("T1")
axs[0,1].plot(npst[:,1])
axs[0,1].set_title("T1*")
axs[0,2].plot(npst[:,2])
axs[0,2].set_title("T2")
axs[1,0].plot(npst[:,3])
axs[1,0].set_title("T2*")
axs[1,1].plot(npst[:,4])
axs[1,1].set_title("V")
axs[1,2].plot(npst[:,5])
axs[1,2].set_title("E")
# Out:
# Text(0.5, 1.0, 'E')

# %%
states[-1]
# Out:
# array([967838.542,     76.007,    620.509,      6.091,    415.35 ,
#        353114.251])

# %%
print(np.max(npst, axis=0)-np.min(npst, axis=0))
# Out:
# [  2.17    0.177   0.548   0.102   0.973 106.844]

# %% [markdown]
# The "infected, healthy" state is stable.
#
# Remark : some amplitude on the oscilations of the concentrations of immune effectors.

# %%
np.set_printoptions(precision=3)
np.set_printoptions(suppress=True)
print(np.max(npst, axis=0))
print(np.min(npst, axis=0))
# Out:
# [967839.874     76.097    621.003      6.102    415.852 353170.605]
# [967837.703     75.919    620.455      6.       414.879 353063.761]

# %% [markdown]
# # simulate infected healthy patient with 25% immunity failure

# %%
s = patient.reset(mode="healthy")
s[5] *= .75
dur = 400
nb_steps = int(dur//1e-3)
print(nb_steps)
states = [s]
for i in range(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)
# Out:
# 399999

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
npst = np.array(states)
axs[0,0].plot(npst[:,0])
axs[0,0].set_title("T1")
axs[0,1].plot(npst[:,1])
axs[0,1].set_title("T1*")
axs[0,2].plot(npst[:,2])
axs[0,2].set_title("T2")
axs[1,0].plot(npst[:,3])
axs[1,0].set_title("T2*")
axs[1,1].plot(npst[:,4])
axs[1,1].set_title("V")
axs[1,2].plot(npst[:,5])
axs[1,2].set_title("E")
# Out:
# Text(0.5, 1.0, 'E')

# %%
states[-1]
# Out:
# array([163571.954,  11944.936,      4.995,     45.599,  63918.578,
#            23.568])

# %%
print(np.max(npst, axis=0)-np.min(npst, axis=0))
# Out:
# [804348.743  20501.33     617.999     39.599 106102.952 292389.951]

# %%
np.set_printoptions(precision=3)
np.set_printoptions(suppress=True)
print(np.max(npst, axis=0))
print(np.min(npst, axis=0))
# Out:
# [967839.003  20577.33     621.        45.599 106517.95  292413.519]
# [163490.26      76.         3.001      6.       414.998     23.568]

# %% [markdown]
# # State bounds

# %%
from tqdm import trange

patient = HIVPatient(clipping=False,logscale=False)
trajs = []
trajs_title = []
dur = 800
nb_steps = int(dur//1e-3)
# uninfected
s = patient.reset(mode="uninfected")
states = [s]
for i in trange(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)
trajs.append(states)
trajs_title.append("uninfected")

# early infection
s = patient.reset(mode="uninfected")
s[1] = 1e-4
s[3] = 1e-4
s[4] = 1
states = [s]
for i in trange(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)
trajs.append(states)
trajs_title.append("early infection")

# infected healthy
s = patient.reset(mode="healthy")
states = [s]
for i in trange(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)
trajs.append(states)
trajs_title.append("healthy")

# infected healthy with 25% immunity failure
s = patient.reset(mode="healthy")
s[5] *= .75
states = [s]
for i in trange(nb_steps):
    s1 = s + patient.der(s,patient.action_set[0])*1e-3
    s = s1
    states.append(s)
trajs.append(states)
trajs_title.append("25% immunity fail")
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 799999/799999 [00:11<00:00, 70262.88it/s]

# %%
nptrajs = np.array(trajs)
print(nptrajs.shape)
# Out:
# (4, 800000, 6)

# %%
print(nptrajs[:,0,:])
print(np.log10(nptrajs[:,0,:]))
# Out:
# [[1000000.       0.    3198.       0.       0.      10.]
#  [1000000.       0.    3198.       0.       1.      10.]
#  [ 967839.      76.     621.       6.     415.  353108.]
#  [ 967839.      76.     621.       6.     415.  264831.]]
# [[ 6.      -inf  3.505   -inf   -inf  1.   ]
#  [ 6.    -4.     3.505 -4.     0.     1.   ]
#  [ 5.986  1.881  2.793  0.778  2.618  5.548]
#  [ 5.986  1.881  2.793  0.778  2.618  5.423]]
# /tmp/ipykernel_255/3725939153.py:2: RuntimeWarning: divide by zero encountered in log10
#   print(np.log10(nptrajs[:,0,:]))

# %%
print(np.min(nptrajs, axis=(0,1)))
print(np.max(nptrajs, axis=(0,1)))
# Out:
# [14226.477     0.        0.117     0.        0.       10.   ]
# [1000000.     512971.065    3198.       2167.062 2726641.237  353170.605]

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
var_names = ["T1", "T1*", "T2", "T2*", "V", "E"]

for var_idx, ax in enumerate(fig.axes):
    for traj_idx in range(nptrajs.shape[0]):
        ax.plot(nptrajs[traj_idx,:,var_idx], label=trajs_title[traj_idx])
    ax.set_title(var_names[var_idx])
    ax.legend()

# %%
bounds = np.zeros((2,6))
bounds[1,0] = 1e6
bounds[1,1] = 5e4
bounds[1,2] = 3200
bounds[1,3] = 80
bounds[1,4] = 2.5e5
bounds[1,5] = 353200

nptrajs_clipped = nptrajs.copy()

for i in range(nptrajs_clipped.shape[2]):
    np.clip(nptrajs_clipped[:,:,i], bounds[0,i], bounds[1,i], out=nptrajs_clipped[:,:,i]);

print(np.min(nptrajs_clipped, axis=(0,1)))
print(np.max(nptrajs_clipped, axis=(0,1)))
# Out:
# [14226.477     0.        0.117     0.        0.       10.   ]
# [1000000.      50000.       3198.         80.     250000.     353170.605]

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
var_names = ["T1", "T1*", "T2", "T2*", "V", "E"]

for var_index, ax in enumerate(fig.axes):
    for traj in range(nptrajs.shape[0]):
        ax.plot(nptrajs_clipped[traj,:,var_index], label=trajs_title[traj])
    ax.set_title(var_names[var_index])
    ax.legend()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
var_names = ["T1", "T1*", "T2", "T2*", "V", "E"]

for var_index, ax in enumerate(fig.axes):
    for traj in range(nptrajs.shape[0]):
        ax.plot(np.log10(nptrajs_clipped[traj,:,var_index]), label=trajs_title[traj])
    ax.set_title(var_names[var_index])
    ax.legend()
# Out:
# /tmp/ipykernel_255/3844828333.py:6: RuntimeWarning: divide by zero encountered in log10
#   ax.plot(np.log10(nptrajs_clipped[traj,:,var_index]), label=trajs_title[traj])
# /tmp/ipykernel_255/3844828333.py:6: RuntimeWarning: divide by zero encountered in log10
#   ax.plot(np.log10(nptrajs_clipped[traj,:,var_index]), label=trajs_title[traj])
# /tmp/ipykernel_255/3844828333.py:6: RuntimeWarning: divide by zero encountered in log10
#   ax.plot(np.log10(nptrajs_clipped[traj,:,var_index]), label=trajs_title[traj])

# %% [markdown]
# # Test step() function

# %%
s = patient.reset(mode="healthy")
s[5] *= .75
patient.E *= .75
print(patient.E)
dur = 80 # 400/5
nb_steps = int(dur//1e-3)
states = [s]
for i in range(dur):
    s, r, d, _ = patient.step(0)
    states.append(s)
# Out:
# 264831.0

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 15))
npst = np.array(states)
axs[0,0].plot(npst[:,0])
axs[0,0].set_title("T1")
axs[0,1].plot(npst[:,1])
axs[0,1].set_title("T1*")
axs[0,2].plot(npst[:,2])
axs[0,2].set_title("T2")
axs[1,0].plot(npst[:,3])
axs[1,0].set_title("T2*")
axs[1,1].plot(npst[:,4])
axs[1,1].set_title("V")
axs[1,2].plot(npst[:,5])
axs[1,2].set_title("E")
# Out:
# Text(0.5, 1.0, 'E')

# %% [markdown]
# ### Créer le buffer

# %% [markdown]
# ### Fitted Q Iteration

# %%
s = patient.reset()
