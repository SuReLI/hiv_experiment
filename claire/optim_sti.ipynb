# %% [markdown]
# # FQI

# %%
from FQI import FQI

fqi = FQI(npatients=30)
r,s,a = fqi.train()
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# mean reward over tested patients =  3432807.6803915706
# mean reward over tested patients =  3652153.312549548
# mean reward over tested patients =  53535675.957794875
# mean reward over tested patients =  96771475.42678322
# mean reward over tested patients =  85099364.52233598
# mean reward over tested patients =  101830876.20310001
# mean reward over tested patients =  83176190.23092288
# mean reward over tested patients =  2123436002.9798095
# mean reward over tested patients =  3149638953.470289
# mean reward over tested patients =  8101588671.606683

# %%
import matplotlib.pyplot as plt
import numpy as np

state_labels = ['T1','T1*','T2','T2*','V','E']
for i in range(len(state_labels)):
    plt.plot([t for t in range(200)],np.log10(s[-1][:,i]))
    plt.title(state_labels[i])
    plt.show()

# %% [markdown]
# # DQN

# %%
from DDQN import DDQN
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
ddqn = DDQN(npatients=5,device=device)
r,s,a = ddqn.train()
# Out:
# /home/ubuntu/SDD/ml/reinforcement_learning/hiv_experiment/claire/DDQN.py:26: UserWarning: This overload of addcmul is deprecated:
# 	addcmul(Tensor input, Number value, Tensor tensor1, Tensor tensor2, *, Tensor out)
# Consider using one of the following signatures instead:
# 	addcmul(Tensor input, Tensor tensor1, Tensor tensor2, *, Number value, Tensor out) (Triggered internally at  ../torch/csrc/utils/python_arg_parser.cpp:1050.)
#   update = torch.addcmul(R,self.gamma,1-D,QS2max)
# mean reward over tested patients =  4552236.179818021
# mean reward over tested patients =  13361041.28938214
# mean reward over tested patients =  13930686.0341723
# mean reward over tested patients =  6677047.843907171
# mean reward over tested patients =  6677047.843907171
# mean reward over tested patients =  6677047.843907171
# mean reward over tested patients =  6677047.843907171
# mean reward over tested patients =  6677047.843907171
# mean reward over tested patients =  7581658.017227739

# %%
import matplotlib.pyplot as plt
import numpy as np

state_labels = ['T1','T1*','T2','T2*','V','E']
for i in range(len(state_labels)):
    plt.plot([t for t in range(200)],np.log10(s[-1][:,i]))
    plt.title(state_labels[i])
    plt.show()
