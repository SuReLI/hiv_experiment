# %% [markdown]
# # FQI

# %%
from fitted_q_iteration import FQI

fqi = FQI()
r,s,a = fqi.learn()
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# mean reward over tested patients =  3432807.6803915715
# mean reward over tested patients =  3652153.312549549
# mean reward over tested patients =  9461079.676471317
# mean reward over tested patients =  12938155.023162803
# mean reward over tested patients =  12880784.346139492
# mean reward over tested patients =  32858261.96903931
# mean reward over tested patients =  363596985.0909371
# mean reward over tested patients =  538205626.087385
# mean reward over tested patients =  3593974389.2120066
# mean reward over tested patients =  844526102.9287776

# %%
import matplotlib.pyplot as plt
import numpy as np

state_labels = ['T1','T1*','T2','T2*','V','E']
for i in range(len(state_labels)):
    plt.plot([t for t in range(200)],np.log10(s[:,i]))
    plt.title(state_labels[i])
    plt.show()

# %% [markdown]
# Maybe increase number of patients for sampling to 30 (here is 5) like in paper to have more similar results?

# %% [markdown]
# # DQN

# %%
from DQN import DQN # Doesn't work yet

dqn = DQN()
dqn.learn()
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# /home/ubuntu/anaconda3/envs/pie-rl/lib/python3.8/site-packages/torch/nn/modules/loss.py:520: UserWarning: Using a target size (torch.Size([200, 1])) that is different to the input size (torch.Size([200, 4])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /home/ubuntu/SDD/ml/reinforcement_learning/hiv_experiment/DQN.py:132: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:201.)
#   a = self.Qn.model(torch.Tensor([s])).argmax(1)[0].detach()
# ...
